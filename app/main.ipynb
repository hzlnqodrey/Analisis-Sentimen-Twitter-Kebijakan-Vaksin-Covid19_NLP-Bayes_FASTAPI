# %%
import pandas as pd

# %%
data = pd.read_csv('hasil_klasifikasi_naive_bayes_data_tweet_8k.csv', )

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Text                    8000 non-null   object
#  1   Text_English            8000 non-null   object
#  2   Klasifikasi_NLP         8000 non-null   object
#  3   Klasifikasi_NaiveBayes  8000 non-null   object
# dtypes: object(4)
# memory usage: 250.1+ KB

# %%
result = []

for index, row in list(data.iterrows()):
    result.append(row)

# %%
result
# Out:
# [Text                      dulu barat upn warung kayuh bambai bumbu haban...
#  Text_English              in the past, the western upn stall, the caulif...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 0, dtype: object,
#  Text                              segala sakit disalahin vaksin covid lieur
#  Text_English              all illnesses are blamed for the covid lieur v...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 1, dtype: object,
#  Text                      bukankah kamu dulu bagian rezim setelah terdep...
#  Text_English              didn't you used to be part of the regime, afte...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 2, dtype: object,
#  Text                      saya kan ganti lama dulu covid menyerang sudah...
#  Text_English              i changed it a long time ago, when covid attac...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 3, dtype: object,
#  Text                      terus  masku kena covid kek sudah  endemi masi ae
#  Text_English              then my mask got covid kek it's already endemi...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 4, dtype: object,
#  Text                      covid-19 subvarian xbb dilaporkan telah masuk ...
#  Text_English              covid-1' subvariant xbb is reported to have en...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 5, dtype: object,
#  Text                      covid-19 subvarian xbb masuk bali kabar kemenk...
#  Text_English              covid-1' subvariant xbb has entered bali, the ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 6, dtype: object,
#  Text                      pemerintah kerajaan arab saudi menyatakan masi...
#  Text_English              the government of the kingdom of saudi arabia ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 7, dtype: object,
#  Text                       sakit tekak level covid ritu tak sakit mcmni
#  Text_English              covid level sore throat doesn't hurt like thi
#  Klasifikasi_NLP                                                  Netral
#  Klasifikasi_NaiveBayes                                           Netral
#  Name: 8, dtype: object,
#  Text                      menteri kesehatan ri meminta masyarakat mewasp...
#  Text_English              the minister of health of the republic of indo...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 9, dtype: object,
#  Text                      kementerian kesehatan ri meminta masyarakat me...
#  Text_English              ri's ministry of health asked the public to be...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 10, dtype: object,
#  Text                      malaysia mendapatkan vaksin bivalen pfizer dik...
#  Text_English              malaysia receives pfizer bivalent vaccine upda...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 11, dtype: object,
#  Text                      kemenkes minta waspadai penularan covid - awal...
#  Text_English              the ministry of health asked to be aware of th...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 12, dtype: object,
#  Text                      covid baya remember
#  Text_English                covid baya rememb
#  Klasifikasi_NLP                        Netral
#  Klasifikasi_NaiveBayes                 Netral
#  Name: 13, dtype: object,
#  Text                      saya kena covid tempat kerja paksa saya dapatk...
#  Text_English              i have covid at the forced workplace, i get mc...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 14, dtype: object,
#  Text                      buat swab test dulu  qib bhya skarang nie dmam...
#  Text_English              buat swab test dulu qib bhya skarang nie dmam ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 15, dtype: object,
#  Text                      tapi  benar  anjir sejak habis covid rasanya j...
#  Text_English              but it's true that since the end of covid, it ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 16, dtype: object,
#  Text                      tidak  usah covid ding flu biasa saja  sekaran...
#  Text_English              no need for covid ding, just the usual flu now...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 17, dtype: object,
#  Text                      sekarang takutnya bukan cuma covid saja  stampede
#  Text_English               now i'm afraid it's not just covid, it's stamped
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 18, dtype: object,
#  Text                      niru kebijakan pandemi covid kemarin  direalis...
#  Text_English              imitating yesterday's covid pandemic policy re...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 19, dtype: object,
#  Text                      covid darjat
#  Text_English              covid darjat
#  Klasifikasi_NLP                 Netral
#  Klasifikasi_NaiveBayes          Netral
#  Name: 20, dtype: object,
#  Text                      pns wafat kena covid terus  mereka rekrut pega...
#  Text_English              civil servants die from covid and they recruit...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 21, dtype: object,
#  Text                      kalau  meriang/batuk2 mending langsung tes cov...
#  Text_English              if you have a fever/cough, it's better to take...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 22, dtype: object,
#  Text                        igt demam biasa tiber covid pulak
#  Text_English              it's like a normal fever with covid
#  Klasifikasi_NLP                                       Positif
#  Klasifikasi_NaiveBayes                                 Netral
#  Name: 23, dtype: object,
#  Text                      beberapa faktor gangguan pembekuan darah dipik...
#  Text_English              several factors for blood clotting disorders a...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 24, dtype: object,
#  Text                      fitphonelive jam bersama dokter gigi  jusuf ph...
#  Text_English                  fitphonelive jam with dentist jusuf ph dhanya
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 25, dtype: object,
#  Text                      virus covid-19 masih berada sekeliling kita pa...
#  Text_English              the covid-1' virus is still around us wearing ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 26, dtype: object,
#  Text                      tragedi itaewonpuan euforia kerumuman massa pa...
#  Text_English              itaewonpuan tragedy the euphoria of the post-c...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 27, dtype: object,
#  Text                      harga minyak merosot akhir perdagangan senin s...
#  Text_English              oil prices slumped late monday tuesday morning...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 28, dtype: object,
#  Text                      good morning semua kepada kena covid speedy re...
#  Text_English              good morning everyone to those affected by cov...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 29, dtype: object,
#  Text                      walaupun kita fasa peralihan endemik amalkan l...
#  Text_English              even though we are in the endemic transition p...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 30, dtype: object,
#  Text                      jangan teledor covid-19 masih varian xbb milik...
#  Text_English              don't be careless about covid-1', but the xbb ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 31, dtype: object,
#  Text                      aduh covid omicron xbb pulakkk
#  Text_English                     ouch, covid omicron xbb
#  Klasifikasi_NLP                                   Netral
#  Klasifikasi_NaiveBayes                            Netral
#  Name: 32, dtype: object,
#  Text                      intinya manusia harus sehat sehat terkena covi...
#  Text_English              the point is that humans must be healthy, heal...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 33, dtype: object,
#  Text                      monggo kagem masyarakat belum vaksinasi covid-...
#  Text_English              please be amazed that the community has not be...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 34, dtype: object,
#  Text                      kayaknya  saya  covid
#  Text_English               i think i have covid
#  Klasifikasi_NLP                          Netral
#  Klasifikasi_NaiveBayes                   Netral
#  Name: 35, dtype: object,
#  Text                      lamalama dari  umum sama  sp jakarta  harus me...
#  Text_English              long ago from the general public and sp jakart...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 36, dtype: object,
#  Text                          haish tiba-tiba badan dedar hope jangan covid
#  Text_English              haish suddenly the body is shaking, hope it's ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 37, dtype: object,
#  Text                      proyek menghidupkan orang mati china
#  Text_English                 project of raising the dead china
#  Klasifikasi_NLP                                        Negatif
#  Klasifikasi_NaiveBayes                                  Netral
#  Name: 38, dtype: object,
#  Text                      seragam bupati jember barang bukti korupsi hon...
#  Text_English              jember regent uniform as evidence of corruptio...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 39, dtype: object,
#  Text                      kemenkes laporkan kasus covid-19 varian xbb ka...
#  Text_English              ministry of health reports case of covid-1' va...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 40, dtype: object,
#  Text                      menteri bumn mengajak semua pihak untuk  memba...
#  Text_English              the minister of state-owned enterprises invite...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 41, dtype: object,
#  Text                      nenek saya  juga  pas meninggal bicara  katany...
#  Text_English              when my grandmother also died, she said when s...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 42, dtype: object,
#  Text                             kantor ramai  covid lagi  tbtb orang  kena
#  Text_English              the office is busy with covid again tbtb peopl...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 43, dtype: object,
#  Text                      lorong haji taib lorong haji taib fokus penyam...
#  Text_English              taib hajj lane taib hajj lane focus on providi...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 44, dtype: object,
#  Text                      gelombang covid-19 teruskan penjarakan sosial ...
#  Text_English              wave of covid-1' continue social distancing we...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 45, dtype: object,
#  Text                      kira-kira semua pasien pernah terpapar covid k...
#  Text_English              approximately all patients have been exposed t...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 46, dtype: object,
#  Text                       tahun covid-19tahun invasi militer rusia ukraina
#  Text_English              year of covid-1'year of military invasion of r...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 47, dtype: object,
#  Text                      cuti bersama natal tahun ditiadakan covid-19cu...
#  Text_English              christmas holiday year abolished covid-1' chri...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 48, dtype: object,
#  Text                      sebuah tragedi dunia bulan oktober awal oktobe...
#  Text_English              a world tragedy in october early october to la...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 49, dtype: object,
#  Text                      hai saya  baru first time tekene covid teramat...
#  Text_English              hi, this is the first time i have signed up fo...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 50, dtype: object,
#  Text                      jalan mega kecil jalan sekutu fokus penyampaia...
#  Text_English              small mega road, allied road, focus on deliver...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 51, dtype: object,
#  Text                      makin lama korang sedar tak populasi dunia mak...
#  Text_English              the longer you realize the world's population ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 52, dtype: object,
#  Text                      saya ingat pupus doh covid sbb lamo tak dengar...
#  Text_English              i remember that covid died because i haven't h...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 53, dtype: object,
#  Text                      cekizenpandemi belum usai terdapat varian covi...
#  Text_English              checking the zenpandemic is not over, there is...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 54, dtype: object,
#  Text                      warga lampung bangkit pemprov lampung tekan an...
#  Text_English              lampung residents rise up lampung provincial g...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 55, dtype: object,
#  Text                      covid selesai  populasi tetap terkikis kenapa ...
#  Text_English              covid is over the population is still eroding ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 56, dtype: object,
#  Text                           kasus covid-19 kabupaten asmat meningkat
#  Text_English              covid-1' cases in asmat district have increas
#  Klasifikasi_NLP                                                  Netral
#  Klasifikasi_NaiveBayes                                           Netral
#  Name: 57, dtype: object,
#  Text                      tips penjagaan kendiri rumah pesakit covid-19 ...
#  Text_English              tips for self-care at home for covid-1' influe...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 58, dtype: object,
#  Text                      ppa presint -12b blok b2 ppa presint -12b blok...
#  Text_English              ppa precinct -12b block b2 ppa precinct -12b b...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 59, dtype: object,
#  Text                      kebijakan covid-19 data ekonomi china melemahk...
#  Text_English              china's covid-1' economic data policy weakens ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 60, dtype: object,
#  Text                      one thing dont like about covid os batuk kerin...
#  Text_English              one thing don't like about covid os dry cough ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 61, dtype: object,
#  Text                      sebaliknya jangan  mentang2 anda merasa sakit ...
#  Text_English              conversely, don't be afraid that you feel sick...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 62, dtype: object,
#  Text                      covid-19 varian xbb telah masuk malaysia ditem...
#  Text_English              the covid-1' variant of xbb has entered malays...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 63, dtype: object,
#  Text                      covid-19 varian xbb telah masuk malaysia ditem...
#  Text_English              the covid-1' variant of xbb has entered malays...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 64, dtype: object,
#  Text                      depa cakap kena pakai mask balik while saya ri...
#  Text_English              you said you have to wear a mask again while i...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 65, dtype: object,
#  Text                      jokowi visioner bermental pengusaha risk taker...
#  Text_English              jokowi is visionary, has the mentality of bein...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 66, dtype: object,
#  Text                      pedagang pasar cihapit mulai beralih iklim dig...
#  Text_English              cihapit market traders are starting to switch ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 67, dtype: object,
#  Text                      iya samaaa saya tidak  dibolehin gara masi cov...
#  Text_English                      yes, i'm not allowed because of covid tim
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 68, dtype: object,
#  Text                      sumpah semenjak kena covid itu  tenggorokan ke...
#  Text_English              i swear that since i got covid, my throat is v...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 69, dtype: object,
#  Text                      cegah penularan covid-19 ayo tuntaskan vaksina...
#  Text_English              prevent the transmission of covid-1' let's com...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 70, dtype: object,
#  Text                      film mirip  dulu jelas2 kita dulu tertipu indo...
#  Text_English              films similar to the past, clearly we were dec...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 71, dtype: object,
#  Text                      tempatku buanyak sekali  batuk kering ataupun ...
#  Text_English              where i have lots of dry coughs or phlegm wher...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 72, dtype: object,
#  Text                      pengunjung disney resort shanghai tidak bisa k...
#  Text_English              disney resort shanghai visitors can't get out ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 73, dtype: object,
#  Text                      kementerian kesehatan kemenkes menargetkan imp...
#  Text_English              the ministry of health the ministry of health ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 74, dtype: object,
#  Text                      saya menyesal terlanjur vaksin selesai vaksin ...
#  Text_English              i regret that the vaccine has finished, the va...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 75, dtype: object,
#  Text                      anggota polsek sidareja melaksanakan ops yusti...
#  Text_English              members of the sidareja police carry out the o...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 76, dtype: object,
#  Text                      covid-19 varian xbb telah masuk malaysia ditem...
#  Text_English              the covid-1' variant of xbb has entered malays...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 77, dtype: object,
#  Text                      anggota polsek sidareja melaksanakan ops yusti...
#  Text_English              members of the sidareja police carry out the o...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 78, dtype: object,
#  Text                      puan euforia kerumuman massa pasca-covid harus...
#  Text_English              ladies euphoria after the post-covid mass crow...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 79, dtype: object,
#  Text                      anggota polsek sidareja melaksanakan ops yusti...
#  Text_English              members of the sidareja police carry out the o...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 80, dtype: object,
#  Text                      hmmm positive covid again and kalini rsa macam...
#  Text_English              hmmm positive covid again and this time it fee...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 81, dtype: object,
#  Text                      anggota polsek sidareja melaksanakan ops yusti...
#  Text_English              members of the sidareja police carry out the o...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 82, dtype: object,
#  Text                      kejadiannya mirip  pembangunan rs daerah provi...
#  Text_English              what happened was similar to the construction ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 83, dtype: object,
#  Text                      covid matame lpm
#  Text_English              covid matame lpm
#  Klasifikasi_NLP                     Netral
#  Klasifikasi_NaiveBayes              Netral
#  Name: 84, dtype: object,
#  Text                      covid-19 kapitalisme teori konspirasi lewat
#  Text_English               covid-1' capitalism conspiracy theory pass
#  Klasifikasi_NLP                                                Netral
#  Klasifikasi_NaiveBayes                                         Netral
#  Name: 85, dtype: object,
#  Text                      berawal pernah menjadi penyitas covid merasaka...
#  Text_English              starting from being a covid survivor, he felt ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 86, dtype: object,
#  Text                      bodo sial macam  gini kena covid
#  Text_English               stupid shit like this got covid
#  Klasifikasi_NLP                                    Negatif
#  Klasifikasi_NaiveBayes                              Netral
#  Name: 87, dtype: object,
#  Text                      mudarat pergi luar negara turki masa covid bal...
#  Text_English              it's harmful to go abroad in turkey during cov...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 88, dtype: object,
#  Text                      tahun pertahankan sebabkan lalai sikit je pert...
#  Text_English              years of defending because i was a little negl...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 89, dtype: object,
#  Text                      khawatir covid-19 pengunjung terjebak disneyla...
#  Text_English              worried about covid-1' visitors getting stuck ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 90, dtype: object,
#  Text                      pasien covid-19 sembuh indonesia naik orang pe...
#  Text_English              covid-1' patients recovering in indonesia incr...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 91, dtype: object,
#  Text                      pasien covid meninggal indonesia bertambah ora...
#  Text_English              covid-1' patients die in indonesia, an increas...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 92, dtype: object,
#  Text                      orang inodnesia telah divaksin covid-19 dosis ...
#  Text_English              indonesian people have been vaccinated against...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 93, dtype: object,
#  Text                      wow thanks for doing this saya berharap tahun ...
#  Text_English              wow, thanks for doing this, i hope that my yea...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 94, dtype: object,
#  Text                      pemerintah pantau suspek covid-19 periksa spes...
#  Text_English              the government is monitoring suspected covid-1...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 95, dtype: object,
#  Text                      semoga pasien covid-19 diberikan sekembuhan ha...
#  Text_English              i hope that the covid-1' patient will be given...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 96, dtype: object,
#  Text                      bila janji lapor keuntungan formulae tidak  te...
#  Text_English              if the promise to report the benefits of the f...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 97, dtype: object,
#  Text                      menkeu sri mulyani pandemi covid-19 kondisi ge...
#  Text_English              minister of finance sri mulyani the covid-1' p...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 98, dtype: object,
#  Text                           puncak covid-19 omicron xbb prediksi januari
#  Text_English              peak of covid-1' omicron xbb predictions for j...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 99, dtype: object,
#  Text                      tetangga ku malah covid juga  meninggal mendad...
#  Text_English              my neighbor even had covid, he also died sudde...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 100, dtype: object,
#  Text                      kemenkes warga ri sduah divaksinasi covid-19 d...
#  Text_English              the ministry of health of the republic of indo...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 101, dtype: object,
#  Text                      kemenkes warga ri divaksinasi covid-19 dosis p...
#  Text_English              indonesian ministry of health vaccinated the f...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 102, dtype: object,
#  Text                      kemenkes infeksi covid-19 varian xbb indonesia...
#  Text_English              ministry of health infection of the indonesian...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 103, dtype: object,
#  Text                      pas covid lagi  tinggi
#  Text_English                  when covid is high
#  Klasifikasi_NLP                          Positif
#  Klasifikasi_NaiveBayes                    Netral
#  Name: 104, dtype: object,
#  Text                      malaysia temukan empat kasus covid-19 subvaria...
#  Text_English              malaysia finds four cases of covid-1' subvaria...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 105, dtype: object,
#  Text                      setelah covid bunuh banyak  orang  seakan alam...
#  Text_English              after covid killed many people as if nature ha...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 106, dtype: object,
#  Text                      kasus covid-19 meningkat malaysia anjurkan pem...
#  Text_English              covid-1' cases are increasing, malaysia recomm...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 107, dtype: object,
#  Text                      punithan dijatuhi hukuman mati mei orang perta...
#  Text_English              punithan sentenced to death may first person s...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 108, dtype: object,
#  Text                      billi khuwab mai chichre isi brazil sadar ko c...
#  Text_English              billi khuwab mai chichre isi brazil sadar ko c...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 109, dtype: object,
#  Text                      kadang  mikir andai covid iki tidak  ono what ...
#  Text_English              sometimes i think if covid didn't go on, what ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 110, dtype: object,
#  Text                      mengajak keluarga treking sentul paling oke li...
#  Text_English              inviting the sentul trekking family is the bes...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 111, dtype: object,
#  Text                      wuhan lockdown covid-19 kasus harian china tem...
#  Text_English              wuhan lockdown covid-1' china daily cases pass...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 112, dtype: object,
#  Text                      setuju perniagaan keci boleh boleh covid kilan...
#  Text_English              i agree that small business can be covid, fact...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 113, dtype: object,
#  Text                      bukan angin duduk salah vaksin cara tidak  ken...
#  Text_English              it's not the wind sitting wrong vaccine how to...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 114, dtype: object,
#  Text                      meninggal kena covid
#  Text_English                     died of covid
#  Klasifikasi_NLP                         Netral
#  Klasifikasi_NaiveBayes                  Netral
#  Name: 115, dtype: object,
#  Text                      bila kumtaja magufuli kisufuria kinawasha magu...
#  Text_English              without mentioning magufuli, the pot is lit, m...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 116, dtype: object,
#  Text                      heee anda bloon kalau  tragedi kanjuruhan mati...
#  Text_English              heee, you are dumb if the tragedy demands that...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 117, dtype: object,
#  Text                        guru murid tembaki disekolah
#  Text_English              teacher pupils shoot at school
#  Klasifikasi_NLP                                   Netral
#  Klasifikasi_NaiveBayes                            Netral
#  Name: 118, dtype: object,
#  Text                        guru murid tembaki disekolah
#  Text_English              teacher pupils shoot at school
#  Klasifikasi_NLP                                   Netral
#  Klasifikasi_NaiveBayes                            Netral
#  Name: 119, dtype: object,
#  Text                              situasi terkini covid selangor
#  Text_English              the latest covid situation in selangor
#  Klasifikasi_NLP                                          Positif
#  Klasifikasi_NaiveBayes                                    Netral
#  Name: 120, dtype: object,
#  Text                      melaksanakan himbauan protokol kesehatan covid...
#  Text_English              implementing the covid-1' health protocol appe...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 121, dtype: object,
#  Text                        guru murid tembaki disekolah
#  Text_English              teacher pupils shoot at school
#  Klasifikasi_NLP                                   Netral
#  Klasifikasi_NaiveBayes                            Netral
#  Name: 122, dtype: object,
#  Text                       efek musim pancaroba apa covid orang2 sakit gini
#  Text_English              what is the effect of the transition season or...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 123, dtype: object,
#  Text                      bumi seleksi alam belum cukup apa sama covid k...
#  Text_English              earth natural selection is not enough what wit...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 124, dtype: object,
#  Text                      update data uji pacar  covid-19 indonesia per ...
#  Text_English              update on indonesia's covid-1' boyfriend test ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 125, dtype: object,
#  Text                      sherehe za1 kuzindua daraja wami2 kuzindua sen...
#  Text_English              1st ceremony to launch my bridge 2nd to launch...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 126, dtype: object,
#  Text                        sekali kapitalisme pandemi covid-19 - via
#  Text_English              once the covid-1' pandemic capitalism - via
#  Klasifikasi_NLP                                                Netral
#  Klasifikasi_NaiveBayes                                         Netral
#  Name: 127, dtype: object,
#  Text                       kasus covid-19 tinggi kota malang ppkm level
#  Text_English              covid-1' cases are high in malang, ppkm level
#  Klasifikasi_NLP                                                 Positif
#  Klasifikasi_NaiveBayes                                           Netral
#  Name: 128, dtype: object,
#  Text                      covid belum selesai masih varian baru + kasusn...
#  Text_English              covid isn't finished yet, there's still a new ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 129, dtype: object,
#  Text                      gelombang kecil kasus covid-19 terjadi menjela...
#  Text_English              a small wave of covid-1' cases occurred ahead ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 130, dtype: object,
#  Text                      kalau  covid bakal anggaran ngalir
#  Text_English                   if covid the budget will flow
#  Klasifikasi_NLP                                       Netral
#  Klasifikasi_NaiveBayes                                Netral
#  Name: 131, dtype: object,
#  Text                      kejar kebijakan nol-covid-19 china lockdown ju...
#  Text_English              pursue china's zero-covid-1' policy lockdown m...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 132, dtype: object,
#  Text                      mkc covid bad ye hi bawasir sab jagah
#  Text_English              mkc covid bad ye hi bawasir sab jagah
#  Klasifikasi_NLP                                         Negatif
#  Klasifikasi_NaiveBayes                                   Netral
#  Name: 133, dtype: object,
#  Text                      pembatasan karena  covid mulai dihilangkan ter...
#  Text_English              the restrictions because covid began to be rem...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 134, dtype: object,
#  Text                      foto pas masih jaman covid saja  yaa free pas ...
#  Text_English              just take a photo during the covid era, okay, ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 135, dtype: object,
#  Text                      abhi saal bol rha tha jb sudhara to pe aa gaya...
#  Text_English              abhi saal bol rha tha jb sudhara to pe aa gaya...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 136, dtype: object,
#  Text                      vaksinasi masih kena covid benar-benar safe an...
#  Text_English              vaccination against covid is really safe and e...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 137, dtype: object,
#  Text                              satgas kasus covid-19 ri bertambah orang
#  Text_English              the ri task force for covid-1' cases has increas
#  Klasifikasi_NLP                                                     Netral
#  Klasifikasi_NaiveBayes                                              Netral
#  Name: 138, dtype: object,
#  Text                      pemerintah kota sukabumi melaporkan stok vaksi...
#  Text_English              the sukabumi city government reports that the ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 139, dtype: object,
#  Text                      neraya factors due to covid some compromises i...
#  Text_English              neraya factors due to covid some compromises i...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 140, dtype: object,
#  Text                      malaysia siap gelar pemilu tengah gelombang co...
#  Text_English              malaysia is ready to hold elections amid the w...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 141, dtype: object,
#  Text                      titi con covid kajdkadk quackity dios
#  Text_English              titi with covid kajdkadk quackity god
#  Klasifikasi_NLP                                          Netral
#  Klasifikasi_NaiveBayes                                   Netral
#  Name: 142, dtype: object,
#  Text                      maisha kizungu ndio raha mapinduzi siku zingin...
#  Text_English              white life is pleasure, revolution, some days ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 143, dtype: object,
#  Text                        le dio covid titi jabakasbskanansjajajaj
#  Text_English              le dio covid street jabakasbskanansjajajaj
#  Klasifikasi_NLP                                               Netral
#  Klasifikasi_NaiveBayes                                        Netral
#  Name: 144, dtype: object,
#  Text                      le dio covid titi jabakasbskanans
#  Text_English               le dio covid titi jabakasbskanan
#  Klasifikasi_NLP                                      Netral
#  Klasifikasi_NaiveBayes                               Netral
#  Name: 145, dtype: object,
#  Text                      saan parte naging matalino ang luthengutong ut...
#  Text_English              where did the luthengutong idiot the potekhawa...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 146, dtype: object,
#  Text                      bri kini sedang menerapkan transformasi digita...
#  Text_English              bri is currently implementing digital transfor...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 147, dtype: object,
#  Text                      kalau  saya sendiri kalau  tidak  covid kemari...
# ...
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 950, dtype: object,
#  Text                      pelaksanaan dewg demm presidensi g20 indonesia...
#  Text_English              the implementation of the dewg demm presidency...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 951, dtype: object,
#  Text                      iyo we wedi covid saya
#  Text_English                iyo we wedi my covid
#  Klasifikasi_NLP                           Netral
#  Klasifikasi_NaiveBayes                    Netral
#  Name: 952, dtype: object,
#  Text                      tiap update berita covid varian baru banyak tu...
#  Text_English              every time the covid news update, the new vari...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 953, dtype: object,
#  Text                      update data uji pacar  covid-19 indonesia per ...
#  Text_English              update on indonesia's covid-1' boyfriend test ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 954, dtype: object,
#  Text                      update infografis percepatan penanganan covid-...
#  Text_English              infographic update on the acceleration of indo...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 955, dtype: object,
#  Text                      aat kondisi krisis global pasca covid dampak p...
#  Text_English              aat post-covid global crisis conditions the im...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 956, dtype: object,
#  Text                      yuk simak rekapan datanya konten atas ikuti te...
#  Text_English              come on, look at the content data summary. kee...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 957, dtype: object,
#  Text                      ato bisa penyebab penyakit covid sendiriklo ba...
#  Text_English              or could it be the cause of the disease itself...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 958, dtype: object,
#  Text                      update mingguan covid-1924 oktober - oktober i...
#  Text_English              weekly update covid-1'24 october - october wan...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 959, dtype: object,
#  Text                      malaysia menghadapi gelombang kecil covid-19 k...
#  Text_English              malaysia is facing a small wave of covid-1' ca...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 960, dtype: object,
#  Text                      saya juga  pasien long covid varian delta pasc...
#  Text_English              i am also a long covid patient, the delta vari...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 961, dtype: object,
#  Text                      okelah kalau  vaksin memang  bisa pilih  harus...
#  Text_English              it's okay if you can choose a vaccine, it must...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 962, dtype: object,
#  Text                      habis selesai covid langsung tidak  tratur bulan
#  Text_English              after finishing covid, it doesn't go straight ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 963, dtype: object,
#  Text                          covid bisa jaringan parut kaya tbc
#  Text_English              covid can scar tissue like tuberculosi
#  Klasifikasi_NLP                                           Netral
#  Klasifikasi_NaiveBayes                                    Netral
#  Name: 964, dtype: object,
#  Text                      jagak friends tetap jaga prokes ketat jaga kes...
#  Text_English              take care of friends, keep strict health proto...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 965, dtype: object,
#  Text                      kabar terbaru datang varian baru covid-19 tela...
#  Text_English              the latest news is that a new variant of covid...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 966, dtype: object,
#  Text                      halloween budaya barat tidak  faedahnya begitu...
#  Text_English              halloween in western culture is not useful so ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 967, dtype: object,
#  Text                       untung wes tidak  covid mana
#  Text_English              fortunately wes not covid wher
#  Klasifikasi_NLP                                  Positif
#  Klasifikasi_NaiveBayes                            Netral
#  Name: 968, dtype: object,
#  Text                      lancau kena covid
#  Text_English               lancao has covid
#  Klasifikasi_NLP                      Netral
#  Klasifikasi_NaiveBayes               Netral
#  Name: 969, dtype: object,
#  Text                      agak mirip covid masa iya covid memang  masi a...
#  Text_English              it's a bit like the covid period, yes, the cov...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 970, dtype: object,
#  Text                      menkes budi covid-19 subvarian omicron xbb mas...
#  Text_English              minister of health budi covid-1' subvariant om...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 971, dtype: object,
#  Text                      puan maharani euforia kerumuman massa pasca-co...
#  Text_English              puan maharani euphoria post-covid mass crowds ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 972, dtype: object,
#  Text                      covid-19 kes baharu direkodkan minggu epidemio...
#  Text_English              new covid-1' cases were recorded in the 4'rd e...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 973, dtype: object,
#  Text                      bersyukur tahun bandung tidak  pernah dapat  m...
#  Text_English              i'm grateful that bandung has never had this p...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 974, dtype: object,
#  Text                      haid tidak  teratur bukannya efek vaksin baikn...
#  Text_English              irregular menstruation instead of the effect o...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 975, dtype: object,
#  Text                      band sheila on memulai aktivitasnya usai pande...
#  Text_English              the band sheila on started its activities afte...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 976, dtype: object,
#  Text                      angkatan kakel saya katanya bulan januari taun...
#  Text_English              i said my class was in january next year. i do...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 977, dtype: object,
#  Text                      izin polisi ribu orang izin satgas covid/parek...
#  Text_English              permits from the police, thousands of people, ...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 978, dtype: object,
#  Text                      giat sat pol airud polresta cilacap senin -10-...
#  Text_English              active sat pol airud polresta cilacap monday -...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 979, dtype: object,
#  Text                      harga minyak dunia anjlok persen imbas meningk...
#  Text_English              world oil prices have plummeted as a result of...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 980, dtype: object,
#  Text                      fenomena yogya covid-19 naik akhir pekan melan...
#  Text_English              the phenomenon of yogya covid-1' rises on week...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 981, dtype: object,
#  Text                      wes baik  kok covid jenis anyar neh iki kawin ...
#  Text_English              it's good that this is a new type of covid. it...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 982, dtype: object,
#  Text                      penyesuaian harga bbm menyelamatkan apbn terma...
#  Text_English              adjusting fuel prices saves the state budget, ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 983, dtype: object,
#  Text                      malaysia berdepan gelombang kecil covid-10 sus...
#  Text_English              malaysia is facing a small wave of covid-10 fo...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 984, dtype: object,
#  Text                      kadang saya  bingung barusan saya  share sc pe...
#  Text_English              sometimes i'm confused just now i share sc car...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 985, dtype: object,
#  Text                           ko covid lagi
#  Text_English              i always have covid
#  Klasifikasi_NLP                        Netral
#  Klasifikasi_NaiveBayes                 Netral
#  Name: 986, dtype: object,
#  Text                      covid jauh2 plisss
#  Text_English              covid jauh2 plisss
#  Klasifikasi_NLP                       Netral
#  Klasifikasi_NaiveBayes                Netral
#  Name: 987, dtype: object,
#  Text                      kan termasuk anda aman nkri menghadapi pandemi...
#  Text_English              including you are safe in the face of the covi...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 988, dtype: object,
#  Text                      aziz ki atakuepo mtaani kutoa hamasa katika zo...
#  Text_English              aziz, will you be there in the street to give ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 989, dtype: object,
#  Text                      travel insurance islam xcover covid sedangkat ...
#  Text_English              travel insurance islam xcover covid while taka...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 990, dtype: object,
#  Text                      if spa2 muhyidin punya parti menang pru boleh ...
#  Text_English              if spa2 muhyidin has a party that wins pru the...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 991, dtype: object,
#  Text                      kasus covid-19 melonjak sejalan temuan varian ...
#  Text_English              covid-1' cases have jumped in line with the fi...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 992, dtype: object,
#  Text                      samaaaakkk saya ngeh sangat  itu  pas jaman2 o...
#  Text_English              it's the same, i really understand that when p...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 993, dtype: object,
#  Text                      aman kok saya waktu cuma sempet ditanyain saja...
#  Text_English              how come it's safe for me when i only got aske...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 994, dtype: object,
#  Text                      tolong  jangan covid tolong  tolong  sedih sek...
#  Text_English              please don't covid please please be so sad it'...
#  Klasifikasi_NLP                                                     Negatif
#  Klasifikasi_NaiveBayes                                              Negatif
#  Name: 995, dtype: object,
#  Text                      covid pulang kampung uncle mbah kung fauci mba...
#  Text_English              covid returned to the village uncle mbah kung ...
#  Klasifikasi_NLP                                                      Netral
#  Klasifikasi_NaiveBayes                                               Netral
#  Name: 996, dtype: object,
#  Text                      iyaa benar  sangat  masih covid gini pas antig...
#  Text_English              yes, it's true, it's still covid like this whe...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 997, dtype: object,
#  Text                      kes covid trend menaik itu  keep your mask on ...
#  Text_English              kes covid trend is up keep your mask on some o...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 998, dtype: object,
#  Text                      sheila on hibur sheilagank lagi  ini  sushimit...
#  Text_English              sheila on entertains sheilagank again this is ...
#  Klasifikasi_NLP                                                     Positif
#  Klasifikasi_NaiveBayes                                              Positif
#  Name: 999, dtype: object,
#  ...]

# %%
data.sample(n=10)

# %%
data['Klasifikasi_NLP'].value_counts()

# %%
data['Klasifikasi_NaiveBayes'].value_counts()

# %%
# pd.set_option('colheader_justify', 'center')   # FOR TABLE <th>

html_string = '''
<html>
    <head><title>Hasil Analisis Sentinment Twitter dengan Algoritma Klasifikasi Naive Bayes</title></head>
    <link rel="stylesheet" type="text/css" href="table_style.css"/>
    <body>
        {table}
    </body>
</html>.
'''

# OUTPUT AN HTML FILE
with open('index.html', 'w') as f:
    f.write(html_string.format(table=data.to_html(classes='mystyle')))

# %%
# fetch data asli
